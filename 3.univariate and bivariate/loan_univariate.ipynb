# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("preprocessedloan_data.csv")

# %%
dataset
# Out:
#       loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 0           1                  2        9600000      29900000          12
# 1           2                  0        4100000      12200000           8
# 2           3                  3        9100000      29700000          20
# 3           4                  3        8200000      30700000           8
# 4           5                  5        9800000      24200000          20
# ...       ...                ...            ...           ...         ...
# 4264     4265                  5        1000000       2300000          12
# 4265     4266                  0        3300000      11300000          20
# 4266     4267                  2        6500000      23900000          18
# 4267     4268                  1        4100000      12800000           8
# 4268     4269                  1        9200000      29700000          10
#
#        cibil_score   residential_assets_value   commercial_assets_value  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    income_annum              4269 non-null   int64
#  3    loan_amount               4269 non-null   int64
#  4    loan_term                 4269 non-null   int64
#  5    cibil_score               4269 non-null   int64
#  6    residential_assets_value  4269 non-null   int64
#  7    commercial_assets_value   4269 non-null   int64
#  8    luxury_assets_value       4269 non-null   int64
#  9    bank_asset_value          4269 non-null   int64
#  10   education_ Not Graduate   4269 non-null   int64
#  11   self_employed_ Yes        4269 non-null   int64
#  12   loan_status_ Rejected     4269 non-null   int64
# dtypes: int64(13)
# memory usage: 433.7 KB

# %%
dataset.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' income_annum', ' loan_amount',
#        ' loan_term', ' cibil_score', ' residential_assets_value',
#        ' commercial_assets_value', ' luxury_assets_value', ' bank_asset_value',
#        ' education_ Not Graduate', ' self_employed_ Yes',
#        ' loan_status_ Rejected'],
#       dtype='object')

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
dataset["loan_id"].dtypes
# Out:
# dtype('int64')

# %%
for columnName in dataset.columns:
    print(columnName)
# Out:
# loan_id
#  no_of_dependents
#  income_annum
#  loan_amount
#  loan_term
#  cibil_score
#  residential_assets_value
#  commercial_assets_value
#  luxury_assets_value
#  bank_asset_value
#  education_ Not Graduate
#  self_employed_ Yes
#  loan_status_ Rejected

# %%
if(dataset["loan_id"].dtype=='O'):
    print("qual")
else:
        print("quan")
# Out:
# quan

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    print(columnName)
    if(dataset[columnName].dtype=='O'):
        print("qual")
        qual.append(columnName)
    else:
        print("quan")
        quan.append(columnName)
# Out:
# loan_id
# quan
#  no_of_dependents
# quan
#  income_annum
# quan
#  loan_amount
# quan
#  loan_term
# quan
#  cibil_score
# quan
#  residential_assets_value
# quan
#  commercial_assets_value
# quan
#  luxury_assets_value
# quan
#  bank_asset_value
# quan
#  education_ Not Graduate
# quan
#  self_employed_ Yes
# quan
#  loan_status_ Rejected
# quan

# %%
def quanqual(dataset):   #function
        quan=[]
        qual=[]
        for columnName in dataset.columns:
               # print(columnName)
                if(dataset[columnName].dtype=='O'):
                    #print("qual")
                    qual.append(columnName)
                else:
                   # print("quan")
                    quan.append(columnName)
        return quan,qual

# %%
quan
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' education_ Not Graduate',
#  ' self_employed_ Yes',
#  ' loan_status_ Rejected']

# %%
qual
# Out:
# []

# %%
dataset.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# Mean       NaN               NaN           NaN          NaN        NaN
# Median     NaN               NaN           NaN          NaN        NaN
# Mode       NaN               NaN           NaN          NaN        NaN
#
#         cibil_score  residential_assets_value  commercial_assets_value  \
# Mean            NaN                       NaN                      NaN
# Median          NaN                       NaN                      NaN
# Mode            NaN                       NaN                      NaN
#
#         luxury_assets_value  bank_asset_value  education_ Not Graduate  \
# Mean                    NaN               NaN                      NaN
# Median                  NaN               NaN                      NaN
# Mode                    NaN               NaN                      NaN
#
#         self_employed_ Yes  loan_status_ Rejected
# Mean                   NaN                    NaN
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan) 
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#        loan_id  no_of_dependents    income_annum      loan_amount  loan_term  \
# Mean    2135.0          2.498712  5059123.916608  15133450.456781  10.900445
# Median  2135.0               3.0       5100000.0       14500000.0       10.0
# Mode         1                 4         7000000         10600000          6
#
#         cibil_score  residential_assets_value  commercial_assets_value  \
# Mean     599.936051            7472616.537831           4973155.305692
# Median        600.0                 5600000.0                3700000.0
# Mode            348                    400000                        0
#
#         luxury_assets_value  bank_asset_value  education_ Not Graduate  \
# Mean        15126305.926446    4976692.433825                 0.497775
# Median           14600000.0         4600000.0                      0.0
# Mode                2900000           1400000                        0
#
#         self_employed_ Yes  loan_status_ Rejected
# ...

# %%
import numpy as np

# %%
np.percentile(dataset["loan_id"],10)
# Out:
# 427.8

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%"],columns=quan) 
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    #descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)-------->it gives NaN value in salary
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

# %%
descriptive
# Out:
#          loan_id  no_of_dependents    income_annum      loan_amount  \
# Mean      2135.0          2.498712  5059123.916608  15133450.456781
# Median    2135.0               3.0       5100000.0       14500000.0
# Mode           1                 4         7000000         10600000
# Q1:25%    1068.0               1.0       2700000.0        7700000.0
# Q2:50%    2135.0               3.0       5100000.0       14500000.0
# Q3:75%    3202.0               4.0       7500000.0       21500000.0
# 99%      4226.32               5.0       9800000.0       35700000.0
# Q4:100%   4269.0               5.0       9900000.0       39500000.0
#
#          loan_term  cibil_score  residential_assets_value  \
# Mean     10.900445   599.936051            7472616.537831
# Median        10.0        600.0                 5600000.0
# Mode             6          348                    400000
# Q1:25%         6.0        453.0                 2200000.0
# Q2:50%        10.0        600.0                 5600000.0
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan) 
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    #descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)-------->it gives NaN value in salary
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]= descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]= descriptive[columnName]["Q3:75%"]+descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#          loan_id  no_of_dependents    income_annum      loan_amount  \
# Mean      2135.0          2.498712  5059123.916608  15133450.456781
# Median    2135.0               3.0       5100000.0       14500000.0
# Mode           1                 4         7000000         10600000
# Q1:25%    1068.0               1.0       2700000.0        7700000.0
# Q2:50%    2135.0               3.0       5100000.0       14500000.0
# Q3:75%    3202.0               4.0       7500000.0       21500000.0
# 99%      4226.32               5.0       9800000.0       35700000.0
# Q4:100%   4269.0               5.0       9900000.0       39500000.0
# IQR       2134.0               3.0       4800000.0       13800000.0
# 1.5rule   3201.0               4.5       7200000.0       20700000.0
# lesser   -2133.0              -3.5      -4500000.0      -13000000.0
# greater   4270.0               5.0      10200000.0       29200000.0
# min            1                 0          200000           300000
# ...

# %%
lesser=[]
greater=[]
for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# [' loan_amount',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["lesser"]]= descriptive[columnName]["lesser"]
                        #check lesser columnName "hsc_p" with dataset hsc_P and replace it with the value descriptive
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["greater"]]= descriptive[columnName]["greater"]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan) 
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    #descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)-------->it gives NaN value in salary
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]= descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]= descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
lesser=[]
greater=[]
for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset["loan_id"].value_counts()
# Out:
# 1       1
# 2852    1
# 2838    1
# 2839    1
# 2840    1
#        ..
# 1430    1
# 1431    1
# 1432    1
# 1433    1
# 4269    1
# Name: loan_id, Length: 4269, dtype: int64

# %%
freq_table=pd.DataFrame(columns=["Unique_values","Frequency","Relative frequency","Cumsum"])
freq_table
# Out:
# Empty DataFrame
# Columns: [Unique_values, Frequency, Relative frequency, Cumsum]
# Index: []

# %%
freq_table["Unique_values"]=dataset["loan_id"].value_counts().index
freq_table["Frequency"]=dataset["loan_id"].value_counts().values
freq_table["Relative frequency"]=(freq_table["Frequency"]/103)
freq_table["Cumsum"]=freq_table["Relative frequency"].cumsum()
def freq_Table(columnName,dataset):
    freq_table=pd.DataFrame(columns=["Unique_values","Frequency","Relative frequency","Cumsum"])
    freq_table["Unique_values"]=dataset[columnName].value_counts().index
    freq_table["Frequency"]=dataset[columnName].value_counts().values
    freq_table["Relative frequency"]=(freq_table["Frequency"]/103)
    freq_table["Cumsum"]=freq_table["Relative frequency"].cumsum()
    return freq_Table

# %%
freq_Table(columnName,dataset)
# Out:
# <function __main__.freq_Table(columnName, dataset)>

# %%
def Univariate(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan) 
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        #descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)-------->it gives NaN value in salary
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["lesser"]= descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
        descriptive[columnName]["greater"]= descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["min"]=dataset[columnName].min()
        descriptive[columnName]["max"]=dataset[columnName].max()

    return descriptive

# %%
Univariate(dataset,quan)
# Out:
#          loan_id  no_of_dependents    income_annum      loan_amount  \
# Mean      2135.0          2.498712  5059123.916608  14878847.505271
# Median    2135.0               3.0       5100000.0       14500000.0
# Mode           1                 4         7000000         29200000
# Q1:25%    1068.0               1.0       2700000.0        7700000.0
# Q2:50%    2135.0               3.0       5100000.0       14500000.0
# Q3:75%    3202.0               4.0       7500000.0       21500000.0
# 99%      4226.32               5.0       9800000.0       29200000.0
# Q4:100%   4269.0               5.0       9900000.0       29200000.0
# IQR       2134.0               3.0       4800000.0       13800000.0
# 1.5rule   3201.0               4.5       7200000.0       20700000.0
# lesser   -2133.0              -3.5      -4500000.0      -13000000.0
# greater   6403.0               8.5      14700000.0       42200000.0
# min            1                 0          200000           300000
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max","kurtosis","skew"],columns=quan) 
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    #descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)-------->it gives NaN value in salary
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]= descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]= descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()
    descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
    descriptive[columnName]["skew"]=dataset[columnName].skew()

# %%
descriptive
# Out:
#           loan_id  no_of_dependents    income_annum      loan_amount  \
# Mean       2135.0          2.498712  5059123.916608  14878847.505271
# Median     2135.0               3.0       5100000.0       14500000.0
# Mode            1                 4         7000000         29200000
# Q1:25%     1068.0               1.0       2700000.0        7700000.0
# Q2:50%     2135.0               3.0       5100000.0       14500000.0
# Q3:75%     3202.0               4.0       7500000.0       21500000.0
# 99%       4226.32               5.0       9800000.0       29200000.0
# Q4:100%    4269.0               5.0       9900000.0       29200000.0
# IQR        2134.0               3.0       4800000.0       13800000.0
# 1.5rule    3201.0               4.5       7200000.0       20700000.0
# lesser    -2133.0              -3.5      -4500000.0      -13000000.0
# greater    6403.0               8.5      14700000.0       42200000.0
# min             1                 0          200000           300000
# ...
